// %%
var sc = require('skale-engine').context();

$$async$$ = sc.textFile(__dirname + '/james_joyce_ulysse.txt')
	.flatMap(line => line.split(' '))
	.map(word => [word, 1])
	.reduceByKey((a, b) => a + b, 0)
	.sortByKey()
	.collect(function(err, result) {
        $$done$$();
		console.log(result);
		sc.end();
	})
// Out:
// undefined
// [ [ '', 2457 ],
//   [ '"Come', 1 ],
//   [ '"Defects,"', 1 ],
//   [ '"I', 1 ],
//   [ '"Information', 1 ],
//   [ '"J"', 1 ],
//   [ '"Plain', 2 ],
//   [ '"Project', 5 ],
//   [ '"Right', 1 ],
//   [ '"Viator"', 1 ],
//   [ '#4300]', 1 ],
//   [ '$5,000)', 1 ],
//   [ '%', 2 ],
//   [ '&c,', 2 ],
//   [ '&c.', 1 ],
//   [ '\'46.', 1 ],
//   [ '\'92', 1 ],
//   [ '\'AS-IS\'', 1 ],
//   [ '\'Slife,', 1 ],
//   [ '\'TWAS', 1 ],
//   [ '\'Tis', 8 ],
//   [ '\'Tis,', 1 ],
//   [ '\'Twas', 5 ],
//   [ '\'Twixt', 1 ],
//   [ '\'em.', 2 ],
//   [ '\'mid', 1 ],
//   [ '\'neath', 1 ],
//   [ '\'pon', 1 ],
//   [ '\'s', 3 ],
//   [ '\'tis', 4 ],
//   [ '\'twas', 4 ],
//   [ '\'twas.', 1 ],
//   [ '\'twere,', 1 ],
//   [ '("the', 1 ],
//   [ '($1', 1 ],
//   [ '(1', 1 ],
//   [ '(1)', 1 ],
//   [ '(1-7-0),', 1 ],
//   [ '(1/4d,', 1 ],
//   [ '(10/-', 1 ],
//   [ '(1000', 1 ],
//   [ '(17', 1 ],
//   [ '(1880)', 1 ],
//   [ '(1st', 1 ],
//   [ '(2', 2 ],
//   [ '(2)', 1 ],
// ...
